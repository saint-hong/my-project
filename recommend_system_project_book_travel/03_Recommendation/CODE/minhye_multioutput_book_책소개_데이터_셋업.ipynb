# %% [markdown]
# ### 책 소개 데이터 column
#
# - book_intro :  책 소개 요약본
# - into_book : 본문 발췌(인상적인 부분 발췌된 부분)
# - pub_review : 출판사 서평

# %%
bk = pd.read_csv('../DATA/BOOK/df_book_introduction_417.csv')
bk[:2]
# Out:
#             ISBN                                         book_intro  \
# 0  9788956609959  ('펴내는 작품마다 압도적인 서사와 폭발적인 이야기의 힘으로 많은 독자들의 뜨거운 ...
# 1  9788936477936  ('따스한 손길로 마음을 어루만지는 이 시대 선한 이야기꾼 이금이 작가의 장편소설 ...
#
#                                            into_book  \
# 0  정유정의 작품들은 넓은 바다와 들판에서 죽을힘을 다해 적과 싸우는 전사의 투지와 고...
# 1  『알로하, 나의 엄마들』의 세 주인공 버들, 홍주, 송화는 천국을 꿈꾸었지만 지옥 ...
#
#                                           pub_review
# 0  언론ㆍ서점ㆍ출판인이 선정한 올해의 책독자들이 뽑은 올해의 한국소설 1위 악惡은 어떻...
# 1  무엇이 사랑을 낳고 무엇이 인간을 기르는가. 낯선 땅에 뿌리내려 자기만의 방식으로 ...

# %%
len(bk)
# Out:
# 417

# %%
key = pd.read_csv('../DATA/BOOK/total_keyword_book.csv', index_col=0)
key[:2]
# Out:
#    label  category           ISBN                        title author  \
# 0      1         3  9788937437496                           인연    피천득
# 1      1         5  9791129706126  최태성 한국사능력검정시험: 심화(1, 2, 3급)    최태성
#
#   publisher                 new_keyword new_subject
# 0       민음사         시인 수필 오월 박준 박완서 수필집         NaN
# 1     메가스터디  스토리텔링 광개토대왕 기출문제 파이널 압축 막판         NaN

# %%
df_all = pd.merge(key, bk, on='ISBN')
df_all.columns
# Out:
# Index(['label', 'category', 'ISBN', 'title', 'author', 'publisher',
#        'new_keyword', 'new_subject', 'book_intro', 'into_book', 'pub_review'],
#       dtype='object')

# %%
len(df_all)
# Out:
# 417

# %%
df_all
# Out:
#      label  category           ISBN                                 title  \
# 0        1         3  9788937437496                                    인연
# 1        1         5  9791129706126           최태성 한국사능력검정시험: 심화(1, 2, 3급)
# 2        1         5  9788901240114                          다시 쓰는 여성 세계사
# 3        1         1  9788956609959                                 종의 기원
# 4        1         1  9788936477936                           알로하, 나의 엄마들
# ..     ...       ...            ...                                   ...
# 412      1        15  9788947544085         하버드 상위 1퍼센트의 비밀(하드커버 리커버 에디션)
# 413      1        15  9788965963752                                  스틸니스
# 414      1        15  9791158510244  5년 후 나에게 Q&A a Day(2020 로즈골드 특별 한정판)
# 415      1        15  9791158510619                     타이탄의 도구들(리커버 에디션)
# 416      1        15  9791190382175                      더 해빙(The Having)
#
#        author publisher                    new_keyword  \
# 0         피천득       민음사            시인 수필 오월 박준 박완서 수필집
# 1         최태성     메가스터디     스토리텔링 광개토대왕 기출문제 파이널 압축 막판
# 2     매기 앤드루스   웅진지식하우스    페미니즘 여성학 시선 페미니스트 문화정치 역사학자
# 3         정유정      은행나무         인간본성 어머니 작가 한국소설 본성 유진
# 4         이금이        창비     가족 여성 청소년소설 한국소설 장편소설 여성서사
# ..        ...       ...                            ...
# 412       정주영    한국경제신문        월스트리트 자기관리 용기 투자 키신저 엑셀
# 413  라이언 홀리데이      흐름출판         예수 삶의지혜 예술가 집중력 처칠 정치가
# 414    포터 스타일      토네이도  아마존 다이어리북 상상력 카르페디엠 밀리언셀러 에디션
# 415     팀 페리스      토네이도       성공법 크리에이티브 코엘료 파울로 말콤 알랭
# 416       이서윤      수오서재            행운 심리학 부자 뇌과학 구루 토성
#
#                                    new_subject  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                  살인자 인간본성 악인
# 4          한국소설 청소년소설 여성서사 일제강점기 근현대사 가족 여성 엄마
# ..                                         ...
# 412  블랙다이아몬드 성공공식 월스트리트 투자 자기관리 한계 용기 믿음 신념 신호
# 413     삶의지혜 통찰 집중력 창조성 사상가 정치가 예술가 운동선수 정신 영혼
# 414                                   다이어리북 질문
# 415                                        성공법
# 416      삶의변화 행운 바이블 구루 부자 불안 고전 심리학 양자물리학 뇌과학
#
#                                             book_intro  \
# 0    ('오월을 사랑하고 오월을 닮은 시인 피천득 수필집 『인연』. 피천득 특유의 천진함...
# 1                                                  NaN
# 2    ('여성의 삶은 무엇으로 혹은 어떠한 연유로 바뀌고, 형성되며, 재정립돼왔는가. 『...
# 3    ('펴내는 작품마다 압도적인 서사와 폭발적인 이야기의 힘으로 많은 독자들의 뜨거운 ...
# 4    ('따스한 손길로 마음을 어루만지는 이 시대 선한 이야기꾼 이금이 작가의 장편소설 ...
# ..                                                 ...
# 412  ('하버드에서 똑같은 수업을 들으면서도 자신들은 다른 하버드생들과 다르다고 선 긋는...
# 413  ('동서고금을 막론하고 위대한 지도자들, 사상가들, 예술가들, 운동선수들, 그리고 ...
# 414  ('가장 쉽고 지혜로운 방법으로 우리를 깊이 생각하게 하고, 하루하루 성장의 글을 ...
# 415  ('프린스턴 대학교에서 ‘기업가정신’을 강의하는 팀 페리스는 글로벌 CEO, 석학,...
# 416  ('부와 행운을 만나는 출발점, 마법의 감정 Having! 국내 최초로 미국에서 선...
#
#                                              into_book  \
# 0    ■서문에서“산호와 진주는 나의 소원이었다. 그러나 산호와 진주는 바닷속 깊이깊이 거...
# 1    한국사라면 진절머리를 냈었는데..어차피 공부할 거면 큰별쌤 교재로 해야지 싶었어요....
# 2    “최근 읽은 책 중 가장 유용하면서, 읽기의 쾌락에 취할 수 있는 ‘가성비 최고의 ...
# 3    정유정의 작품들은 넓은 바다와 들판에서 죽을힘을 다해 적과 싸우는 전사의 투지와 고...
# 4    『알로하, 나의 엄마들』의 세 주인공 버들, 홍주, 송화는 천국을 꿈꾸었지만 지옥 ...
# ..                                                 ...
# 412  저자는 보통 사람들이 어떻게 사회적 한계를 극복하고 새로운 성공 곡선을 그릴 수 있...
# 413  세상이 빙글빙글 돌아도 흔들리지 않는 것. 흥분하지 않고 행동 하는 것. 반드시 들...
# 414  #난 항상 널 응원해전국 서점 200주 연속 베스트셀러 기념2020 로즈골드 특별 ...
# 415           “이 책은 팀 페리스라는 우리 시대 가장 영향력 있는 거인의 역작이다.”
# 416  “Having은 돈을 쓰는 이 순간 ‘가지고 있음’을 ‘충만하게’ 느끼는 것이에요....
#
#                                             pub_review
# 0    “나의 생활을 구성하는 모든 작고 아름다운 것들을 사랑한다.”-피천득 한국인이 가장...
# 1                                                  NaN
# 2    “전국의 모든 도서관에 다 들어가야 하는 책! 여성 생존의 도구와 증거 100가지를...
# 3    언론ㆍ서점ㆍ출판인이 선정한 올해의 책독자들이 뽑은 올해의 한국소설 1위 악惡은 어떻...
# 4    무엇이 사랑을 낳고 무엇이 인간을 기르는가. 낯선 땅에 뿌리내려 자기만의 방식으로 ...
# ..                                                 ...
# 412  평균의 함정에 빠지지 마라. 사람의 생김새가 각자 다르듯, 재능도 사람마다 다를 수...
# 413  뉴욕 타임스 베스트셀러 1위! 아마존 20주간 연속 베스트셀러, 월스트리트 저널 베...
# 414  일기를 쓴다는 일이 생각보다 꾸준히 안되는 일 중의 하나가 되었다. 매일 밥먹듯, ...
# 415  “이 책을 통해 당신은 팀 페리스를 비롯해 세상에서 가장 혁신적인 인물들을 만날 수...
# 416  세계가 먼저 찾아 읽은 책! 한국 최초 세계 1위 출판사가 선출간한 책! 영미권 비...
#
# [417 rows x 11 columns]

# %%
df_all = df_all[['category', 'ISBN', 'title', 'author', 'publisher', 'new_keyword', 'new_subject', 'book_intro', 'into_book', 'pub_review']]

# %%
df_all[:2]
# Out:
#    category           ISBN                        title author publisher  \
# 0         3  9788937437496                           인연    피천득       민음사
# 1         5  9791129706126  최태성 한국사능력검정시험: 심화(1, 2, 3급)    최태성     메가스터디
#
#                   new_keyword new_subject  \
# 0         시인 수필 오월 박준 박완서 수필집         NaN
# 1  스토리텔링 광개토대왕 기출문제 파이널 압축 막판         NaN
#
#                                           book_intro  \
# 0  ('오월을 사랑하고 오월을 닮은 시인 피천득 수필집 『인연』. 피천득 특유의 천진함...
# 1                                                NaN
#
#                                            into_book  \
# 0  ■서문에서“산호와 진주는 나의 소원이었다. 그러나 산호와 진주는 바닷속 깊이깊이 거...
# 1  한국사라면 진절머리를 냈었는데..어차피 공부할 거면 큰별쌤 교재로 해야지 싶었어요....
#
#                                           pub_review
# 0  “나의 생활을 구성하는 모든 작고 아름다운 것들을 사랑한다.”-피천득 한국인이 가장...
# 1                                                NaN

# %%
isbns = []
for i in range(len(df_all)):
    isbn = str(int(df_all['ISBN'][i]))
    isbns.append(isbn)
len(isbns)

df_all['ISBN'] = isbns
# Out:
# C:\Users\shine\Anaconda3\envs\fc\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 416
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     417 non-null    int64
#  1   ISBN         417 non-null    object
#  2   title        417 non-null    object
#  3   author       417 non-null    object
#  4   publisher    417 non-null    object
#  5   new_keyword  352 non-null    object
#  6   new_subject  285 non-null    object
#  7   book_intro   401 non-null    object
#  8   into_book    417 non-null    object
#  9   pub_review   401 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 55.8+ KB

# %%
df = pd.read_csv('../DATA/BOOK/book_01_03_15_05_noun.csv', index_col=0)

# %%
isbns = []
for i in range(len(df)):
    isbn = str(int(df['ISBN'][i]))
    isbns.append(isbn)
len(isbns)

df['ISBN'] = isbns

# %%
df[:2]
# Out:
#    category           ISBN        title  \
# 0         1  9788956609959        종의 기원
# 1         1  9788936477936  알로하, 나의 엄마들
#
#                                               corpus  \
# 0  펴내는 작품마다 압도적인 서사와 폭발적인 이야기의 힘으로 많은 독자들의 뜨거운 사랑...
# 1  따스한 손길로 마음을 어루만지는 이 시대 선한 이야기꾼 이금이 작가의 장편소설 『알...
#
#                                              corpus3 area company interest  \
# 0  작품 압도 서사 폭발 이야기 힘 독자 사랑 온 작가 정유 정의 장편소설 종 기원 전...   자연      혼자       Kn
# 1  손길 마음 이 시대 이야기 금 작가 장편소설 알로하 나 엄마 사진 장 평생 운명 하...   자연      가족       Kn
#
#   comment
# 0     NaN
# 1     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 416
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  417 non-null    int64
#  1   ISBN      417 non-null    object
#  2   title     417 non-null    object
#  3   corpus    417 non-null    object
#  4   corpus3   417 non-null    object
#  5   area      417 non-null    object
#  6   company   417 non-null    object
#  7   interest  417 non-null    object
#  8   comment   109 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 52.6+ KB

# %%
df_new = pd.merge(df_all, df, on='ISBN')
len(df_new)
# Out:
# 417

# %%
df_new
# Out:
#      category_x           ISBN                               title_x  \
# 0             3  9788937437496                                    인연
# 1             5  9791129706126           최태성 한국사능력검정시험: 심화(1, 2, 3급)
# 2             5  9788901240114                          다시 쓰는 여성 세계사
# 3             1  9788956609959                                 종의 기원
# 4             1  9788936477936                           알로하, 나의 엄마들
# ..          ...            ...                                   ...
# 412          15  9788947544085         하버드 상위 1퍼센트의 비밀(하드커버 리커버 에디션)
# 413          15  9788965963752                                  스틸니스
# 414          15  9791158510244  5년 후 나에게 Q&A a Day(2020 로즈골드 특별 한정판)
# 415          15  9791158510619                     타이탄의 도구들(리커버 에디션)
# 416          15  9791190382175                      더 해빙(The Having)
#
#        author publisher                    new_keyword  \
# 0         피천득       민음사            시인 수필 오월 박준 박완서 수필집
# 1         최태성     메가스터디     스토리텔링 광개토대왕 기출문제 파이널 압축 막판
# 2     매기 앤드루스   웅진지식하우스    페미니즘 여성학 시선 페미니스트 문화정치 역사학자
# 3         정유정      은행나무         인간본성 어머니 작가 한국소설 본성 유진
# 4         이금이        창비     가족 여성 청소년소설 한국소설 장편소설 여성서사
# ..        ...       ...                            ...
# 412       정주영    한국경제신문        월스트리트 자기관리 용기 투자 키신저 엑셀
# 413  라이언 홀리데이      흐름출판         예수 삶의지혜 예술가 집중력 처칠 정치가
# 414    포터 스타일      토네이도  아마존 다이어리북 상상력 카르페디엠 밀리언셀러 에디션
# 415     팀 페리스      토네이도       성공법 크리에이티브 코엘료 파울로 말콤 알랭
# 416       이서윤      수오서재            행운 심리학 부자 뇌과학 구루 토성
#
#                                    new_subject  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                  살인자 인간본성 악인
# 4          한국소설 청소년소설 여성서사 일제강점기 근현대사 가족 여성 엄마
# ..                                         ...
# 412  블랙다이아몬드 성공공식 월스트리트 투자 자기관리 한계 용기 믿음 신념 신호
# 413     삶의지혜 통찰 집중력 창조성 사상가 정치가 예술가 운동선수 정신 영혼
# 414                                   다이어리북 질문
# 415                                        성공법
# 416      삶의변화 행운 바이블 구루 부자 불안 고전 심리학 양자물리학 뇌과학
#
#                                             book_intro  \
# 0    ('오월을 사랑하고 오월을 닮은 시인 피천득 수필집 『인연』. 피천득 특유의 천진함...
# 1                                                  NaN
# 2    ('여성의 삶은 무엇으로 혹은 어떠한 연유로 바뀌고, 형성되며, 재정립돼왔는가. 『...
# 3    ('펴내는 작품마다 압도적인 서사와 폭발적인 이야기의 힘으로 많은 독자들의 뜨거운 ...
# 4    ('따스한 손길로 마음을 어루만지는 이 시대 선한 이야기꾼 이금이 작가의 장편소설 ...
# ..                                                 ...
# 412  ('하버드에서 똑같은 수업을 들으면서도 자신들은 다른 하버드생들과 다르다고 선 긋는...
# 413  ('동서고금을 막론하고 위대한 지도자들, 사상가들, 예술가들, 운동선수들, 그리고 ...
# 414  ('가장 쉽고 지혜로운 방법으로 우리를 깊이 생각하게 하고, 하루하루 성장의 글을 ...
# 415  ('프린스턴 대학교에서 ‘기업가정신’을 강의하는 팀 페리스는 글로벌 CEO, 석학,...
# 416  ('부와 행운을 만나는 출발점, 마법의 감정 Having! 국내 최초로 미국에서 선...
#
#                                              into_book  \
# 0    ■서문에서“산호와 진주는 나의 소원이었다. 그러나 산호와 진주는 바닷속 깊이깊이 거...
# 1    한국사라면 진절머리를 냈었는데..어차피 공부할 거면 큰별쌤 교재로 해야지 싶었어요....
# 2    “최근 읽은 책 중 가장 유용하면서, 읽기의 쾌락에 취할 수 있는 ‘가성비 최고의 ...
# 3    정유정의 작품들은 넓은 바다와 들판에서 죽을힘을 다해 적과 싸우는 전사의 투지와 고...
# 4    『알로하, 나의 엄마들』의 세 주인공 버들, 홍주, 송화는 천국을 꿈꾸었지만 지옥 ...
# ..                                                 ...
# 412  저자는 보통 사람들이 어떻게 사회적 한계를 극복하고 새로운 성공 곡선을 그릴 수 있...
# 413  세상이 빙글빙글 돌아도 흔들리지 않는 것. 흥분하지 않고 행동 하는 것. 반드시 들...
# 414  #난 항상 널 응원해전국 서점 200주 연속 베스트셀러 기념2020 로즈골드 특별 ...
# 415           “이 책은 팀 페리스라는 우리 시대 가장 영향력 있는 거인의 역작이다.”
# 416  “Having은 돈을 쓰는 이 순간 ‘가지고 있음’을 ‘충만하게’ 느끼는 것이에요....
#
#                                             pub_review  category_y  \
# 0    “나의 생활을 구성하는 모든 작고 아름다운 것들을 사랑한다.”-피천득 한국인이 가장...           3
# 1                                                  NaN           5
# 2    “전국의 모든 도서관에 다 들어가야 하는 책! 여성 생존의 도구와 증거 100가지를...           5
# 3    언론ㆍ서점ㆍ출판인이 선정한 올해의 책독자들이 뽑은 올해의 한국소설 1위 악惡은 어떻...           1
# 4    무엇이 사랑을 낳고 무엇이 인간을 기르는가. 낯선 땅에 뿌리내려 자기만의 방식으로 ...           1
# ..                                                 ...         ...
# 412  평균의 함정에 빠지지 마라. 사람의 생김새가 각자 다르듯, 재능도 사람마다 다를 수...          15
# 413  뉴욕 타임스 베스트셀러 1위! 아마존 20주간 연속 베스트셀러, 월스트리트 저널 베...          15
# 414  일기를 쓴다는 일이 생각보다 꾸준히 안되는 일 중의 하나가 되었다. 매일 밥먹듯, ...          15
# 415  “이 책을 통해 당신은 팀 페리스를 비롯해 세상에서 가장 혁신적인 인물들을 만날 수...          15
# 416  세계가 먼저 찾아 읽은 책! 한국 최초 세계 1위 출판사가 선출간한 책! 영미권 비...          15
#
#                                   title_y  \
# 0                                      인연
# 1             최태성 한국사능력검정시험: 심화(1, 2, 3급)
# 2                            다시 쓰는 여성 세계사
# 3                                   종의 기원
# 4                             알로하, 나의 엄마들
# ..                                    ...
# 412         하버드 상위 1퍼센트의 비밀(하드커버 리커버 에디션)
# 413                                  스틸니스
# 414  5년 후 나에게 Q&A a Day(2020 로즈골드 특별 한정판)
# 415                     타이탄의 도구들(리커버 에디션)
# 416                      더 해빙(The Having)
#
#                                                 corpus  \
# 0    오월을 사랑하고 오월을 닮은 시인 피천득 수필집 『인연』. 피천득 특유의 천진함과 ...
# 1    키워드로 핵심잡고, 스토리로 이해하고, 이미지로 기억한다시간과 장소에 구애받지 않도...
# 2    여성의 삶은 무엇으로 혹은 어떠한 연유로 바뀌고, 형성되며, 재정립돼왔는가. 『10...
# 3    펴내는 작품마다 압도적인 서사와 폭발적인 이야기의 힘으로 많은 독자들의 뜨거운 사랑...
# 4    따스한 손길로 마음을 어루만지는 이 시대 선한 이야기꾼 이금이 작가의 장편소설 『알...
# ..                                                 ...
# 412  하버드에서 똑같은 수업을 들으면서도 자신들은 다른 하버드생들과 다르다고 선 긋는 집...
# 413  동서고금을 막론하고 위대한 지도자들, 사상가들, 예술가들, 운동선수들, 그리고 공상...
# 414  가장 쉽고 지혜로운 방법으로 우리를 깊이 생각하게 하고, 하루하루 성장의 글을 쓰게...
# 415  프린스턴 대학교에서 ‘기업가정신’을 강의하는 팀 페리스는 글로벌 CEO, 석학, 언...
# 416  부와 행운을 만나는 출발점, 마법의 감정 Having! 국내 최초로 미국에서 선(先...
#
#                                                corpus3 area company interest  \
# 0    오월 사랑 오월 시인 피천득 수필집 인연 피천득 특유 생각 문 완성 욕심 세계 이번...   자연      가족       Ar
# 1    키 워드 핵심 잡고 스토리 이해 이미지 다시 장소 구애 강의 책 하나로 최태성 한국...   도시      혼자       Kn
# 2    여성 무엇 연유 형성 재정 립 가지 물건 다시 여성 세계사 여성 삶 영향 여성 오늘...   도시      친구       Ar
# 3    작품 압도 서사 폭발 이야기 힘 독자 사랑 온 작가 정유 정의 장편소설 종 기원 전...   자연      혼자       Kn
# 4    손길 마음 이 시대 이야기 금 작가 장편소설 알로하 나 엄마 사진 장 평생 운명 하...   자연      가족       Kn
# ..                                                 ...  ...     ...      ...
# 412  하버드 수업 자신 다른 하버드 생 선 집단 그 하버드 가장 폐쇄적 투자자 집단 블랙...   도시      혼자       Ad
# 413  고금 막론 지도자 사상가 예술가 운동선수 공상가 공통 가지 힘 바로 스틸 니스 스토...   자연      가족       Kn
# 414  가장 지혜 방법 우리 깊이 생각 하루하루 성장 글 후 나 하루 하나 동안 그 답 기...   자연      가족       Ar
# 415  프린스턴 대학교 기업가 정신 강의 팀 페리스 글로벌 학 언론 이 시대 가장 혁신 아...   도시      친구       Ad
# 416  부와 행운 출발점 마법 감정 국내 최초 미국 선 간 세계 먼저 더 해빙 세계 부자 ...   도시      친구       Sh
#
#        comment
# 0          NaN
# 1    한국사 기출문제집
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 412          0
# 413          0
# 414    company
# 415          0
# 416          0
#
# [417 rows x 18 columns]

# %%
df_perfect = df_new[['category_x', 'title_x', 'author', 'publisher', 'new_keyword', 'new_subject', 'book_intro', 'into_book', 'pub_review', 'area', 'company', 'interest']]

# %%
df_perfect[:2]
# Out:
#    category_x                      title_x author publisher  \
# 0           3                           인연    피천득       민음사
# 1           5  최태성 한국사능력검정시험: 심화(1, 2, 3급)    최태성     메가스터디
#
#                   new_keyword new_subject  \
# 0         시인 수필 오월 박준 박완서 수필집         NaN
# 1  스토리텔링 광개토대왕 기출문제 파이널 압축 막판         NaN
#
#                                           book_intro  \
# 0  ('오월을 사랑하고 오월을 닮은 시인 피천득 수필집 『인연』. 피천득 특유의 천진함...
# 1                                                NaN
#
#                                            into_book  \
# 0  ■서문에서“산호와 진주는 나의 소원이었다. 그러나 산호와 진주는 바닷속 깊이깊이 거...
# 1  한국사라면 진절머리를 냈었는데..어차피 공부할 거면 큰별쌤 교재로 해야지 싶었어요....
#
#                                           pub_review area company interest
# 0  “나의 생활을 구성하는 모든 작고 아름다운 것들을 사랑한다.”-피천득 한국인이 가장...   자연      가족       Ar
# 1                                                NaN   도시      혼자       Kn

# %% [markdown]
# ### 데이터 전처리

# %%
df_perfect['temp'] = df_perfect['area'] + df_perfect['company'] + df_perfect['interest'] + df_perfect['title'] + df_perfect['author'] + df_perfect['publisher'] + df_perfect['new_keyword'] + df_perfect['new_subject'] + df_perfect['pub_review']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\fc\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-1648930cdf4d> in <module>
# ----> 1 df_perfect['temp'] = df_perfect['area'] + df_perfect['company'] + df_perfect['interest'] + df_perfect['title'] + df_perfect['author'] + df_perfect['publisher'] + df_perfect['new_keyword'] + df_perfect['new_subject'] + df_perfect['pub_review']
#
# ~\Anaconda3\envs\fc\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\fc\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'

# %%
len(df_perfect['temp'].notnull())
# Out:
# 108

# %%
df_perfect = df_perfect.fillna(' ')

# %% [markdown]
# ### 라벨인코딩

# %%
temp = []
temp.append(list(df_perfect['interest'].unique()))
temp.append(list(df_perfect['area'].unique()))
temp.append(list(df_perfect['company'].unique()))
temp = sum(temp, [])

# %%
temp
# Out:
# ['Ar', 'Ex', 'Sh', 'Kn', 'Ad', 'Et', 'Fo', '자연', '도시', '가족', '혼자', '친구', '허니문']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(temp)
# Out:
# LabelEncoder()

# %%
df_perfect['y1'] = df_perfect['area'].apply(lambda x: le.transform([x])[0])
df_perfect['y2'] = df_perfect['company'].apply(lambda x : le.transform([x])[0])
df_perfect['y3'] = df_perfect['interest'].apply(lambda x : le.transform([x])[0])

# %%
df_perfect[:2]
# Out:
#          title author publisher              new_keyword  \
# 0           인연    피천득       민음사      시인 수필 오월 박준 박완서 수필집
# 1  혼자여서 괜찮은 하루    곽정은       포르체  연애 일상 심리학 한국에세이 위로 마음챙김
#
#                       new_subject  \
# 0
# 1  한국에세이 명상 혼자 소확행 연애 일상 마음챙김 심리학
#
#                                                  int area company interest  \
# 0  오월을 사랑하고 오월을 닮은 시인 피천득 수필집 『인연』. 피천득 특유의 천진함과 ...   자연      가족       Ar
# 1  혼자여서 괜찮은 시간에서 혼자여서 괜찮은 하루로, 나아가 혼자여서 괜찮은 삶을 살아...   도시      혼자       Ex
#
#                                                 temp  y1  y2  y3
# 0  자연가족Ar인연피천득민음사시인 수필 오월 박준 박완서 수필집 오월을 사랑하고 오월을...   9   7   1
# 1  도시혼자Ex혼자여서 괜찮은 하루곽정은포르체연애 일상 심리학 한국에세이 위로 마음챙김...   8  12   3

# %% [markdown]
# ### tfidf vectorize

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer()
X = tf.fit_transform(df_perfect['temp']).toarray()

# %%
Y = np.vstack((np.array(df_perfect['y1']),np.array(df_perfect['y2']),np.array(df_perfect['y3']))).T
Y
# Out:
# array([[ 9,  7,  1],
#        [ 8, 12,  3],
#        [ 9, 12,  1],
#        [ 8,  7,  6],
#        [ 8, 12,  5],
#        [ 8, 10,  3],
#        [ 9,  7,  6],
#        [ 8,  7,  1],
#        [ 9, 12,  1],
#        [ 8, 12,  6],
#        [ 8, 12,  5],
#        [ 8, 12,  1],
#        [ 8,  7,  0],
#        [ 8, 11,  6],
#        [ 9, 12,  6],
#        [ 8, 12,  3],
#        [ 8, 12,  1],
#        [ 9,  7,  1],
#        [ 9, 12,  1],
#        [ 8, 12,  6],
#        [ 9,  7,  1],
#        [ 8, 12,  6],
#        [ 8, 12,  5],
#        [ 8, 10,  6],
#        [ 8, 12,  3],
#        [ 8, 12,  3],
#        [ 9, 12,  1],
#        [ 8, 10,  0],
#        [ 9, 12,  1],
#        [ 9, 10,  1],
#        [ 8, 10,  2],
#        [ 8, 12,  0],
#        [ 9,  7,  1],
#        [ 8, 12,  1],
#        [ 8, 11,  3],
#        [ 9,  7,  1],
#        [ 9, 12,  3],
#        [ 9,  7,  3],
#        [ 8, 12,  0],
#        [ 8, 10,  0],
#        [ 8, 12,  1],
#        [ 8, 10,  4],
#        [ 8, 12,  6],
#        [ 9, 10,  0],
#        [ 9,  7,  3],
#        [ 8,  7,  1],
#        [ 8, 12,  5],
#        [ 8, 10,  3],
#        [ 8, 12,  6],
#        [ 9, 12,  5],
#        [ 8,  7,  5],
#        [ 9,  7,  1],
#        [ 9, 12,  3],
#        [ 9, 12,  3],
#        [ 8, 12,  1],
#        [ 8, 12,  6],
#        [ 8, 12,  1],
#        [ 9,  7,  1],
#        [ 9, 12,  3],
#        [ 8, 12,  6],
#        [ 9, 12,  5],
#        [ 8, 10,  4],
#        [ 9,  7,  3],
#        [ 8,  7,  5],
#        [ 9,  7,  5],
#        [ 9, 12,  1],
#        [ 9,  7,  3],
#        [ 8, 12,  5],
#        [ 8, 10,  3],
#        [ 8, 12,  5],
#        [ 8, 10,  6],
#        [ 9,  7,  4],
#        [ 9, 12,  4],
#        [ 8, 10,  6],
#        [ 8, 10,  6],
#        [ 8,  7,  5],
#        [ 9, 12,  0],
#        [ 9, 12,  5],
#        [ 8, 10,  2],
#        [ 8, 11,  4],
#        [ 8, 12,  0],
#        [ 9, 12,  5],
#        [ 9,  7,  5],
#        [ 9, 12,  3],
#        [ 9,  7,  5],
#        [ 9, 12,  0],
#        [ 9, 12,  1],
#        [ 8, 10,  5],
#        [ 8,  7,  0],
#        [ 8, 11,  4],
#        [ 9,  7,  4],
#        [ 8, 12,  3],
#        [ 9, 12,  0],
#        [ 8, 10,  0],
#        [ 9, 12,  5],
#        [ 8, 12,  2],
#        [ 9, 12,  3],
#        [ 8, 12,  2],
#        [ 8, 12,  5],
#        [ 8, 10,  1],
#        [ 8, 10,  3],
#        [ 8, 12,  0],
#        [ 8, 10,  6],
#        [ 9, 12,  0],
#        [ 9, 12,  0],
#        [ 9, 12,  5],
#        [ 8,  7,  5],
#        [ 8, 10,  6]], dtype=int64)

# %% [markdown]
# ### train, test 나누기

# %%
# train, test split
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=13, test_size=0.1)

# %% [markdown]
# ### multinomial NB

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB

NB = MultinomialNB()
multi_target_NB = MultiOutputClassifier(NB, n_jobs=-1)
model_NB = multi_target_NB.fit(X_train, Y_train)

# %%
model_NB.score(X_test, Y_test)
# Out:
# 0.09090909090909091

# %% [markdown]
# ### Randomforest

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(random_state=2, max_features=60, n_estimators=40)
multi_target_RF = MultiOutputClassifier(RF, n_jobs=-1)
model_RF = multi_target_RF.fit(X_train, Y_train)

# %%
model_RF.score(X_test, Y_test)
# Out:
# 0.09090909090909091
