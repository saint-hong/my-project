# %%
san = pd.read_csv('../data/traveling_type_1_2.csv')
san
# Out:
#    city_name  activity                                          tour_name  \
# 0       산티아고     35402                [단 1명도 출발!소규모 투어] 산티아고 워킹 시티 투어 3시간
# 1       산티아고     68024                             산티아고 시내 워킹투어 (칠레/산티아고)
# 2       산티아고     79101               산티아고 : 포르티요, 잉카 라군, 아콩카구아 파크 프라이빗 투어
# 3       산티아고     79263                            산티아고 : 산타리타 와이너리 반나절 투어
# 4       산티아고     79183                         산티아고 : 카혼 델 마이포 소그룹 피크닉 투어
# 5       산티아고     79305                    산티아고 출발 : 발레 네바도 & 파렐로네스 소규모 투어
# 6       산티아고     79301                        산티아고 : 아침 식사가 포함된 소규모 워킹 투어
# 7       산티아고     79297               산티아고 : 콘차 이 토로 와이너리 투어 (소믈리에 클래스 포함)
# 8       산티아고     79293                    산티아고 출발 : 발파라이소 & 비냐 델 마르 일일 투어
# 9       베네치아     20225          [사진촬영 포함] 베네치아 별밤투어 ( 최대인원 10인의 프리미엄 투어 )
# 10      베네치아     25135  [업계1위] 공인 가이드와 함께하는 베네치아 트윙클 야경투어 (+유럽워킹투어 제공이벤트)
# 11      베네치아     39983                        [투어]부드럽고 여유롭게!! 베네치아시내 야경투어
# ...

# %%
for x in range(0, 36):
    san['keyword'][x] = san['keyword'][x].replace('#', '')

# %%
for x in range(0, 36):
    san['type'][x] = san['type'][x].split('/')

# %%
san['type'][12] = san['type'][12][0].split(',')

# %%
san = san[san['activity'] != 42500]
san.reset_index(inplace=True)
san.tail()
# Out:
#     level_0  index city_name  activity  \
# 30       30     31       하와이      6509
# 31       31     32       하와이     40611
# 32       32     33       하와이      7450
# 33       33     34       하와이     22363
# 34       34     35       하와이     40063
#
#                                             tour_name kind  \
# 30  [투어] 한가족만! 호놀룰루 다운타운시내관광(공항픽업후 호텔 첵인시간동안 ) :: 하와이  NaN
# 31              [투어] 카우아이 일일관광 (와이키키 호텔 픽업) :: 미국/하와이  NaN
# 32                      [투어] 오아후섬 HOT 인기폭발 다이아몬드헤드 일출  NaN
# 33                        [단독투어] 인증샷 투어 - 하와이를 단 하루만에  NaN
# 34                    하와이 : 마우이 할레아칼라 국립 공원 해돋이 일출 투어  NaN
#
#                                  keyword          type     특이사항
# 30  역사 가족 시내 호놀룰루 일본 조선 비극적 와엉 군주 여왕 식민지        [지식추구]      NaN
# 31   공원 도시락 반찬 포케 사진 카우아이 섬 피크닉 자연 바다 해변  [자연친화적, 가족적]      NaN
# 32    등반 일출 정상 등산 운동화 하이킹 다이아몬드헤드 화산 분화구          [모험]      NaN
# 33              아울렛 마트 인증샷 드라이빙 차량 관광 명소  [자연친화적, 도시적]  태그2개고민중
# ...

# %%
df = pd.read_csv('../data/activity_cleared_with_corpus.csv', index_col=0)
df = pd.DataFrame(df)
df = data[['activity', 'info']]
df
# Out:
#     activity                                               info
# 0       9660  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...
# 1       5665  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...
# 2       2097  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...
# 3       5833  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...
# 4       6282  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...
# ..       ...                                                ...
# 67     33306  ※ 학사 일정으로 인하여 투어 진행이 매일 가능하지 않기 때문에 예약 전에 꼭 메세...
# 68     26036  ★예약 주의 사항★ 단체 투어 특성 상, 투어 전 가이드가 개별 연락을 드리지 않습...
# 69     52950  ***** 공인가이드 ‘이다’와 함께 하는 “베네치아 두칼레 투어”는 *****\n...
# 70     17175  [알려드립니다.]\n소수 인원으로만 진행 되었던 워킹 투어를 단독 투어로 바꾸게 되...
# 71     38413  우리에겐 아직 생소한 이름 이탈리아 알프스 돌로미티 !\n\n알프스는 유럽 자연의 ...
#
# [72 rows x 2 columns]

# %%
data = pd.merge(df, san, on='activity', how='inner')
data
# Out:
#     activity                                               info  level_0  \
# 0       9660  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...       18
# 1       5665  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...       19
# 2       2097  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...       20
# 3       5833  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...       21
# 4       6282  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...       22
# 5      10504  뉴욕의 맨하탄 미드타운과 다운타운과 자유의 여신상 페리를 하루에 투어하는 상품입니다...       23
# 6        714  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...       24
# 7         84  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...       25
# 8       5981  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...       26
# 9       6507  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...       27
# 10     41529  웅장한 산맥을 배경으로 즐기는 다양한 액티비티, 쿠알로아 목장투어!\n1850년 경...       28
# 11      6561  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...       29
# ...

# %%
a = 35
for num in range(0, 35):

    if len(data.loc[num]['type']) > 1:
       # data['encoder'].loc[num] = data.loc[num]['encoder'][0]
        data.loc[a] = np.nan
        data.loc[a] = data.loc[num]
        data['type'].loc[a] = data.loc[num]['type'][1]
        a += 1
        # print(a)
        try:
            data.loc[a] = np.nan
            data.loc[a] = data.loc[num]
            data['type'].loc[a] = data.loc[num]['type'][2]
            a += 1
            # print(a)
        except:
            pass

data
# Out:
#     activity                                               info  level_0  \
# 0     9660.0  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...     18.0
# 1     5665.0  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...     19.0
# 2     2097.0  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...     20.0
# 3     5833.0  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...     21.0
# 4     6282.0  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...     22.0
# 5    10504.0  뉴욕의 맨하탄 미드타운과 다운타운과 자유의 여신상 페리를 하루에 투어하는 상품입니다...     23.0
# 6      714.0  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...     24.0
# 7       84.0  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...     25.0
# 8     5981.0  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...     26.0
# 9     6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 10   41529.0  웅장한 산맥을 배경으로 즐기는 다양한 액티비티, 쿠알로아 목장투어!\n1850년 경...     28.0
# 11    6561.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     29.0
# ...

# %%
for num in range(0, 35):
    data['type'].iloc[num] = data.iloc[num]['type'][0]
data
# Out:
#     activity                                               info  level_0  \
# 0     9660.0  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...     18.0
# 1     5665.0  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...     19.0
# 2     2097.0  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...     20.0
# 3     5833.0  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...     21.0
# 4     6282.0  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...     22.0
# 5    10504.0  뉴욕의 맨하탄 미드타운과 다운타운과 자유의 여신상 페리를 하루에 투어하는 상품입니다...     23.0
# 6      714.0  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...     24.0
# 7       84.0  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...     25.0
# 8     5981.0  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...     26.0
# 9     6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 10   41529.0  웅장한 산맥을 배경으로 즐기는 다양한 액티비티, 쿠알로아 목장투어!\n1850년 경...     28.0
# 11    6561.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     29.0
# ...

# %%
data = data.drop([52])

# %%
data
# Out:
#     activity                                               info  level_0  \
# 0     9660.0  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...     18.0
# 1     5665.0  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...     19.0
# 2     2097.0  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...     20.0
# 3     5833.0  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...     21.0
# 4     6282.0  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...     22.0
# 5    10504.0  뉴욕의 맨하탄 미드타운과 다운타운과 자유의 여신상 페리를 하루에 투어하는 상품입니다...     23.0
# 6      714.0  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...     24.0
# 7       84.0  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...     25.0
# 8     5981.0  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...     26.0
# 9     6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 10   41529.0  웅장한 산맥을 배경으로 즐기는 다양한 액티비티, 쿠알로아 목장투어!\n1850년 경...     28.0
# 11    6561.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     29.0
# ...

# %%
data['type'][data['type'] == ' 도시적'] = '도시적'
data['type'][data['type'] == '도시'] = '도시적'

# %%
data['type'][data['type'] == '자연친화적'] = '자연친화'
data['type'][data['type'] == '체험중시'] = '체험중심'
data['type'][data['type'] == '체험추구'] = '체험중심'

# %%
data['type'][data['type'] == '모험적'] = '모험'

# %%
temp = data['type'].unique()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(temp)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['가족적', '도시적', '도전적', '맛집', '모험', '문화예술', '셀피적', '자연친화', '지식추구',
#        '체험중심'], dtype=object)

# %%
data['encoder'] = data['type'].apply(lambda x: le.transform([x])[0])
data
# Out:
#     activity                                               info  level_0  \
# 0     9660.0  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...     18.0
# 1     5665.0  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...     19.0
# 2     2097.0  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...     20.0
# 3     5833.0  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...     21.0
# 4     6282.0  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...     22.0
# 5    10504.0  뉴욕의 맨하탄 미드타운과 다운타운과 자유의 여신상 페리를 하루에 투어하는 상품입니다...     23.0
# 6      714.0  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...     24.0
# 7       84.0  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...     25.0
# 8     5981.0  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...     26.0
# 9     6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 10   41529.0  웅장한 산맥을 배경으로 즐기는 다양한 액티비티, 쿠알로아 목장투어!\n1850년 경...     28.0
# 11    6561.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     29.0
# ...

# %%
data['encoder']
# Out:
# 0     5
# 1     5
# 2     1
# 3     1
# 4     5
# 5     3
# 6     0
# 7     1
# 8     6
# 9     7
# 10    9
# 11    1
# 12    8
# 13    7
# 14    4
# 15    7
# 16    7
# 17    5
# 18    3
# 19    8
# 20    3
# 21    8
# 22    7
# 23    3
# 24    8
# 25    7
# 26    1
# 27    1
# 28    1
# 29    8
# 30    6
# 31    7
# 32    8
# 33    8
# 34    7
# 35    0
# 36    2
# 37    0
# 38    1
# 39    4
# 40    8
# 41    9
# 42    9
# 43    7
# 44    9
# 45    9
# 46    3
# 47    1
# 48    9
# 49    5
# 50    6
# 51    9
# Name: encoder, dtype: int64

# %%
data['temp'] = data['tour_name'] + data['keyword'] + data['info']
data
# Out:
#     activity                                               info  level_0  \
# 0     9660.0  메트로폴리탄은 뉴욕을 대표하는 미술관입니다. 뉴욕 시내 안에만 32개의 미술관이 있...     18.0
# 1     5665.0  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...     19.0
# 2     2097.0  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...     20.0
# 3     5833.0  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...     21.0
# 4     6282.0  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...     22.0
# 5    10504.0  뉴욕의 맨하탄 미드타운과 다운타운과 자유의 여신상 페리를 하루에 투어하는 상품입니다...     23.0
# 6      714.0  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...     24.0
# 7       84.0  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...     25.0
# 8     5981.0  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...     26.0
# 9     6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 10   41529.0  웅장한 산맥을 배경으로 즐기는 다양한 액티비티, 쿠알로아 목장투어!\n1850년 경...     28.0
# 11    6561.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     29.0
# ...

# %% [markdown]
# ## MultiNB

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB  # 다항분포 나이브 베이즈 모델
from sklearn.metrics import accuracy_score  # 정확도 계산

# %%
dtmvector = CountVectorizer()
X_train_dtm = dtmvector.fit_transform(data['temp'])
print(X_train_dtm.shape)
# Out:
# (52, 5710)

# %%
tfidf_transformer = TfidfTransformer()
tfidfv = tfidf_transformer.fit_transform(X_train_dtm)
print(X_train_dtm.shape)
# Out:
# (52, 5710)

# %%
list(data['encoder'])
# Out:
# [5,
#  5,
#  1,
#  1,
#  5,
#  3,
#  0,
#  1,
#  6,
#  7,
#  9,
#  1,
#  8,
#  7,
#  4,
#  7,
#  7,
#  5,
#  3,
#  8,
#  3,
#  8,
#  7,
#  3,
#  8,
#  7,
#  1,
#  1,
#  1,
#  8,
#  6,
#  7,
#  8,
#  8,
#  7,
#  0,
#  2,
#  0,
#  1,
#  4,
#  8,
#  9,
#  9,
#  7,
#  9,
#  9,
#  3,
#  1,
#  9,
#  5,
#  6,
#  9]

# %%
mod = MultinomialNB()
mod.fit(tfidfv, list(data['encoder']))
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
data.loc[26]
# Out:
# activity                                                 20225
# info         ※ 저희가 올린 모든 사진은 별밤 투어 중 가이드가 직접 찍은 사진들 입니다\n\n...
# level_0                                                      9
# index                                                        9
# city_name                                                 베네치아
# tour_name            [사진촬영 포함] 베네치아 별밤투어 ( 최대인원 10인의 프리미엄 투어 )
# kind                                    30대,허니문 여행으로 구매가 많은 상품
# keyword                                           베니스 석양 야경 도시
# type                                                       도시적
# 특이사항                                                       NaN
# encoder                                                      1
# temp         [사진촬영 포함] 베네치아 별밤투어 ( 최대인원 10인의 프리미엄 투어 )베니스 석...
# Name: 26, dtype: object

# %%
X_test_dtm = dtmvector.transform([data['temp'][33]])  # 테스트 데이터를 DTM으로 변환
tfidfv_test = tfidf_transformer.transform(X_test_dtm)  # DTM을 TF-IDF 행렬로 변환

predicted = mod.predict(tfidfv_test)  # 테스트 데이터에 대한 예측

# %%
predicted
# Out:
# array([8])

# %%
data.sort_values('activity')
# Out:
#     activity                                               info  level_0  \
# 7       84.0  방문객으로서 겉으로만 바라보는 관광객놀이에서 벗어나 심도있게 뉴요커의 삶을 알아보고...     25.0
# 6      714.0  뉴욕 단독 차량 투어\n\n뉴욕에서 차량 투어를 통해 하루를 보내 볼까요?\n\n*...     24.0
# 2     2097.0  뉴욕 최고의 감성 투어 야경 투어 입니다.^^\n\n\n*뉴욕의 야경 투어*\n\n...     20.0
# 1     5665.0  (날짜가 막혀 있어도 가능한 날이 있으니 문의 주세요~)\n* 문의시 인원, 희망날...     19.0
# 3     5833.0  ***중요**** 타임스퀘어에 위치한 뉴욕 타임즈 건물 앞에서 뵙고 바로 덤보 브륵...     21.0
# 8     5981.0  [주말투어] 뉴욕 핫 포토 스팟(스냅 포함)\n\n시간이 없으신 가요?? 페이스북이...     26.0
# 4     6282.0  메트로폴리탄 뮤지엄 " 오후 3 시간 "\n\n많은 사람들이 뉴욕에 와서 미술관을 ...     22.0
# 9     6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 35    6507.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     27.0
# 12    6509.0  알로하~\n\n장시간 비행을 마치시고 피곤함속에 공항에 도착하시지만 안타깝게도 호텔...     30.0
# 11    6561.0  알로하~\n\nYJ투어는 단 한가족만 모시는 개인투어를 하와이에서 처음으로 시도한 ...     29.0
# 14    7450.0  오아후섬의 대표 상징인 다이아몬드헤드에서 떠오르는 태양을 볼 수 있는 일출 투어입니...     32.0
# ...

# %%
tfidfv_test
# Out:
# <1x5710 sparse matrix of type '<class 'numpy.float64'>'
# 	with 284 stored elements in Compressed Sparse Row format>

# %%
mod.predict(tfidfv_test)
# Out:
# array([8])

# %%
mod.predict_proba(tfidfv_test)
# Out:
# array([[0.03834711, 0.15789584, 0.01256992, 0.06559635, 0.02465594,
#         0.08095282, 0.0971971 , 0.12302146, 0.30475825, 0.09500522]])
